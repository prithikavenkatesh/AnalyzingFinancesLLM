# %%
try:
    import langchain
    print("Langchain is installed.")
except ImportError:
    print("Langchain is not installed.")
# Out:
# Langchain is installed.

# %%
from langchain_community.document_loaders import PyPDFLoader
import os

documents = []
for file in os.listdir("talks/"):
    if file.endswith(".pdf"):
        pdf_path = os.path.join("talks/", file)
        loader = PyPDFLoader(pdf_path)
        documents.extend(loader.load())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain_community.document_loaders import PyPDFLoader
#       2 import os
#       4 documents = []
#
# ModuleNotFoundError: No module named 'langchain_community'

# %%
# !pip install langchain
# Out:
# Python(39476) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...

# %%
import langchain
print("Langchain is installed.")
# Out:
# Langchain is installed.

# %%
from langchain_community.document_loaders import PyPDFLoader
import os

documents = []
for file in os.listdir("talks/"):
    if file.endswith(".pdf"):
        pdf_path = os.path.join("talks/", file)
        loader = PyPDFLoader(pdf_path)
        documents.extend(loader.load())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from langchain_community.document_loaders import PyPDFLoader
#       2 import os
#       4 documents = []
#
# ModuleNotFoundError: No module named 'langchain_community'

# %%
from langchain.document_loaders import PyPDFLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/RAGmodel_1.0/lib/python3.13/site-packages/langchain/_api/module_import.py:69, in create_importer.<locals>.import_by_name(name)
#      68 try:
# ---> 69     module = importlib.import_module(new_module)
#      70 except ModuleNotFoundError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1310, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# ...

# %%
# !pip install langchain-community
# Out:
# Python(39499) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [langchain-community]ngchain-community]
# ...

# %%
# !pip show langchain-community
# Out:
# Python(39572) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Name: langchain-community
# Version: 0.3.27
# Summary: Community contributed LangChain integrations.
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: /Users/prithikavenkatesh/RAGmodel_1.0/lib/python3.13/site-packages
# Requires: aiohttp, dataclasses-json, httpx-sse, langchain, langchain-core, langsmith, numpy, pydantic-settings, PyYAML, requests, SQLAlchemy, tenacity
# Required-by:

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
import os

documents = []
for file in os.listdir("talks/"):
    if file.endswith(".pdf"):
        pdf_path = os.path.join("talks/", file)
        loader = PyPDFLoader(pdf_path)
        documents.extend(loader.load())

print(f"Loaded {len(documents)} documents.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 4
#       1 import os
#       3 documents = []
# ----> 4 for file in os.listdir("talks/"):
#       5     if file.endswith(".pdf"):
#       6         pdf_path = os.path.join("talks/", file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'talks/'

# %%
import os

# Check current working directory
print("Current Working Directory:", os.getcwd())

# List files and directories in the current working directory
print("Contents:", os.listdir())
# Out:
# Current Working Directory: /Users/prithikavenkatesh/RAGmodel_1.0
# Contents: ['bin', 'Untitled.ipynb', 'include', 'etc', 'pyvenv.cfg', '.gitignore', 'lib', '.ipynb_checkpoints', 'share']

# %%
import os

os.makedirs("talks", exist_ok=True)
print("Directory 'talks/' created.")
# Out:
# Directory 'talks/' created.

# %%
print("Files in 'talks/':", os.listdir("talks"))
# Out:
# Files in 'talks/': ['.ipynb_checkpoints', 'Towards_Zero_Waste_An_In-Depth_Analysis_of_Nationa.pdf']

# %%
from langchain_community.document_loaders import PyPDFLoader

documents = []
for file in os.listdir("talks/"):
    if file.endswith(".pdf"):
        pdf_path = os.path.join("talks/", file)
        loader = PyPDFLoader(pdf_path)
        documents.extend(loader.load())

print(f"Loaded {len(documents)} documents.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/RAGmodel_1.0/lib/python3.13/site-packages/langchain_community/document_loaders/parsers/pdf.py:359, in PyPDFParser.lazy_parse(self, blob)
#     358 try:
# --> 359     import pypdf
#     360 except ImportError:
#
# ModuleNotFoundError: No module named 'pypdf'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 8
#       6         pdf_path = os.path.join("talks/", file)
#       7         loader = PyPDFLoader(pdf_path)
# ----> 8         documents.extend(loader.load())
#      10 print(f"Loaded {len(documents)} documents.")
#
# File ~/RAGmodel_1.0/lib/python3.13/site-packages/langchain_core/document_loaders/base.py:32, in BaseLoader.load(self)
#      30 def load(self) -> list[Document]:
# ...

# %%
# !pip install pypdf
# Out:
# Python(39595) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...

# %%
import pypdf
print("pypdf is installed.")
# Out:
# pypdf is installed.

# %%
from langchain_community.document_loaders import PyPDFLoader

documents = []
for file in os.listdir("talks/"):
    if file.endswith(".pdf"):
        pdf_path = os.path.join("talks/", file)
        loader = PyPDFLoader(pdf_path)
        documents.extend(loader.load())

print(f"Loaded {len(documents)} documents.")
# Out:
# Loaded 26 documents.

# %%
for i, doc in enumerate(documents):
    print(f"Document {i+1}:")
    print(doc.page_content)  # Adjust this based on the structure of the document
    print("---")
# Out:
# Document 1:
# Citation: Almansour, M.; Akrami, M.
# Towards Zero Waste: An In-Depth
# Analysis of National Policies,
# Strategies, and Case Studies in Waste
# Minimisation. Sustainability 2024, 16,
# 10105. https://doi.org/10.3390/
# su162210105
# Academic Editor: Erico Carmona
# Received: 16 September 2024
# Revised: 30 October 2024
# Accepted: 14 November 2024
# Published: 19 November 2024
# Copyright: © 2024 by the authors.
# Licensee MDPI, Basel, Switzerland.
# This article is an open access article
# distributed under the terms and
# conditions of the Creative Commons
# Attribution (CC BY) license (https://
# creativecommons.org/licenses/by/
# 4.0/).
# Review
# Towards Zero Waste: An In-Depth Analysis of National Policies,
# Strategies, and Case Studies in Waste Minimisation
# Mohammed Almansour
#  and Mohammad Akrami *
# Department of Engineering, University of Exeter, Exeter EX4 4QF, UK; ma1003@exeter.ac.uk
# * Correspondence: m.akrami@exeter.ac.uk
# ...

# %%
git add .
git commit -m "Downloaded PDF talks and prepared documents"
# Out:
#   Cell In[21], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax
